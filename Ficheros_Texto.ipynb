# %% [markdown]
# <a href="https://colab.research.google.com/github/mleyvaz/AV/blob/master/Ficheros_Texto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('mi_fichero', 'w') as f:
    f.write('Hola mundo\n')
