# %% [markdown]
# <a href="https://colab.research.google.com/github/mleyvaz/AV/blob/master/Criptograf%C3%ADa_Visual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Librerias 
import numpy as np
import pandas as pd
import cv2  
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image 
import matplotlib.pylab as plt

# %% [markdown]
# #Ejercicio  1 sumar las siguientes imágenes con ella misma
#
# ![image.png](https://media.geeksforgeeks.org/wp-content/uploads/1-500x250-3.jpg
# )

# %%
# 
url1="https://media.geeksforgeeks.org/wp-content/uploads/1-500x250-3.jpg"
image1 = io.imread(url1) 
a=cv2.add(image1,image1)
cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7FBCA06C7D50>

# %% [markdown]
# Ejercicio 3 Realice la sustraccion de la  siguientes 2 imágenes
#
#
# ![image.png](https://media.geeksforgeeks.org/wp-content/uploads/star-1-300x168.jpg
# )
# ![image.png](https://media.geeksforgeeks.org/wp-content/uploads/dot-300x168.jpg
# )

# %%
url1="https://media.geeksforgeeks.org/wp-content/uploads/star-1-300x168.jpg"
url2="https://media.geeksforgeeks.org/wp-content/uploads/dot-300x168.jpg"
image1 = io.imread(url1)  
image2 = io.imread(url2) 
a=cv2.subtract(image1,image2)
cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7FBCA06D04D0>

# %% [markdown]
# Ejercicio 1 Realice las operaciones lógics sobre las siguinetes imágenes

# %%
img1 = np.zeros((400,600), dtype=np.uint8)
img1[100:300,200:400] = 255
img2 = np.zeros((400,600), dtype=np.uint8)
img2 = cv2.circle(img2,(300,200),125,(255),-1)

# %%
cv2_imshow(img1)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=600x400 at 0x7FBCA06C7690>
# <PIL.Image.Image image mode=L size=600x400 at 0x7FBCA06C72D0>

# %% [markdown]
# Ejercicio 1 realice un patron de encriptacion con XOR con l asegunda imagen como clave
