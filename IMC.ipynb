# %% [markdown]
# <a href="https://colab.research.google.com/github/mleyvaz/AV/blob/master/IMC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Indice de Masa Corporal
# # Maikel Leyva

# %%
#@title Texto de título predeterminado { run: "auto" }
Peso = 1 #@param {type:"number"}
Talla = 1 #@param {type:"integer"}
imc=Peso/Talla*Talla
print(imc)
# Out:
# 1.0
