# %% [markdown]
# <a href="https://colab.research.google.com/github/mleyvaz/AV/blob/master/POO_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class persona(): # clase persona
    def __init__(self,nombre,edad): # se inicializa con nombre y edad
        self.nombre=nombre
        self.edad=edad

# %%
maikel=persona("MAikel Leyva", 30)

# %%
Ejercicio 1. Imprimir Edad.
## maikel.nombre
# Out:
# 'MAikel Leyva'
