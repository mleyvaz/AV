# %% [markdown]
# <a href="https://colab.research.google.com/github/mleyvaz/AV/blob/master/Refactorizar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class persona(): # clase persona
    def __init__(self,nombre,edad): # se inicializa con nombre y edad
        self.nombre=nombre
        self.edad=edad

# %%
maikel=persona("MAikel Leyva", 30)

# %%
# refactorice el siguente codigo 
# medinate expresiones aumentadas https://zephyrnet.com/es/10-formas-de-refactorizar-su-c%C3%B3digo-Python/
count=0
for i in  range(20):
  count=count+1
print(count)
# Out:
# 20
